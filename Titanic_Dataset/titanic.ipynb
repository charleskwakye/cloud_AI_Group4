# %% [markdown]
# Titanic dataset

# %%
#import titanic dataset 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xlrd

# %%
#import this file files/titanic3.xls into a dataframe
titanic = pd.read_excel('files/titanic3.xls')
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# Check for missing values

# %%
#check for missing values
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# There are 263 missing values in the Age column.
# There are 1 missing values in the Fare column.
# There are 1014 missing values in the Cabin column.
# There are 2 missing values in the Embarked column.
# There are 823 missing values in the Boat column.
# There are 1188 missing values in the Body column.
# There are 564 missing values in the home.dest column.
# There are 2 missing values in the embarked column.

# %% [markdown]
# Since the many columns have missing values, I would have to drop them all except a column where I can fill with the mean of the column. So columns like Cabin, Boat, Body, home.dest would be dropped.

# %%
#delete features that are not useful
titanic.drop(['name','ticket','cabin','boat','body','home.dest','embarked'], axis=1, inplace=True)
titanic.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare
# 0       1         1  female  29.0000      0      0  211.3375
# 1       1         1    male   0.9167      1      2  151.5500
# 2       1         0  female   2.0000      1      2  151.5500
# 3       1         0    male  30.0000      1      2  151.5500
# 4       1         0  female  25.0000      1      2  151.5500

# %% [markdown]
# To make the dataset usable by a ML algorithm we have to change the categorical features into numerical features. So we have to change the gender in from male to female to 0 and 1 respectively. Also we have to change the Embarked column to numerical values. So we have to change the values in the Embarked column to 0, 1 and 2 respectively.

# %%
titanic['sex'] = titanic['sex'].replace({'male': 1, 'female': 0})

# %% [markdown]
# Lets have some insights on the data
# Lets plot the survival of the sex

# %%
survived = titanic[titanic['survived']==1]["sex"].value_counts()
dead = titanic[titanic['survived']==0]["sex"].value_counts()
df = pd.DataFrame([survived,dead])
df.index = ['survived','Dead']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# Plot the survival based on the classes of the ticket

# %%
survived = titanic[titanic['survived']==1]["pclass"].value_counts().reindex([1, 2, 3])
dead = titanic[titanic['survived']==0]["pclass"].value_counts().reindex([1, 2, 3])
df = pd.DataFrame([survived,dead])
df.index = ['survived','Dead']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# Drop unneccesary features from the dataset

# %%
titanic.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch      fare
# 0       1         1    0  29.0000      0      0  211.3375
# 1       1         1    1   0.9167      1      2  151.5500
# 2       1         0    0   2.0000      1      2  151.5500
# 3       1         0    1  30.0000      1      2  151.5500
# 4       1         0    0  25.0000      1      2  151.5500

# %%
# replace gender male to 1 and female to 0
titanic['sex'] = titanic['sex'].replace({'male': 1, 'female': 0})
titanic.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch      fare
# 0       1         1    0  29.0000      0      0  211.3375
# 1       1         1    1   0.9167      1      2  151.5500
# 2       1         0    0   2.0000      1      2  151.5500
# 3       1         0    1  30.0000      1      2  151.5500
# 4       1         0    0  25.0000      1      2  151.5500

# %%
# Calculate the correlation matrix
corr = titanic.corr()
# Plot the heatmap
sns.heatmap(corr, annot=True, cmap="Blues")
plt.show()

# %%
#remove null values
titanic.dropna(inplace=True)
#see the number of rows and columns

# %%
corr_matrix = titanic.corrwith(titanic['survived'])

sns.barplot(x=corr_matrix.index, y=corr_matrix.values)

plt.xticks(rotation=90)

plt.show()

print(corr_matrix)
# Out:
# pclass     -0.319979
# survived    1.000000
# sex        -0.537719
# age        -0.053958
# sibsp      -0.012657
# parch       0.114091
# fare        0.249164
# dtype: float64

# %%
#plot a boxplot for all the features to see the outliers
plt.figure(figsize=(20,15))
plt.subplot(3,3,1)
sns.boxplot(titanic['pclass'])
plt.subplot(3,3,2)
sns.boxplot(titanic['age'])
plt.subplot(3,3,3)
sns.boxplot(titanic['sibsp'])
plt.subplot(3,3,4)
sns.boxplot(titanic['parch'])
plt.subplot(3,3,5)
sns.boxplot(titanic['fare'])
plt.show()

#show the number of rows and columns
titanic.shape
# Out:
# (1045, 7)

# %% [markdown]
# Removing outliers from the dataset using the interquartile range caused the accuracy of my dataset to reduce. So I decided to leave the outliers in the dataset.
#
# # calculate the IQR for each feature
# Q1 = titanic.quantile(0.25)
# Q3 = titanic.quantile(0.75)
# IQR = Q3 - Q1
#
# # remove the outliers
# titanic = titanic[~((titanic < (Q1 - 1.5 * IQR)) |(titanic > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# titanic.shape

# %%
#plot a boxplot for all the features to see the outliers
plt.figure(figsize=(20,15))
plt.subplot(3,3,1)
sns.boxplot(titanic['pclass'])
plt.subplot(3,3,2)
sns.boxplot(titanic['age'])
plt.subplot(3,3,3)
sns.boxplot(titanic['sibsp'])
plt.subplot(3,3,4)
sns.boxplot(titanic['parch'])
plt.subplot(3,3,5)
sns.boxplot(titanic['fare'])
plt.show()

# %%
#import pycaret
from pycaret.classification import *

# %%
s = setup(titanic, target = 'survived', session_id = 123)
# Out:
# <style type="text/css">
# #T_fc594_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc594">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc594_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fc594_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc594_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc594_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fc594_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc594_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fc594_row1_col1" class="data row1 col1" >survived</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc594_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fc594_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc594_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fc594_row3_col1" class="data row3 col1" >(1045, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc594_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fc594_row4_col1" class="data row4 col1" >(1045, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc594_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fc594_row5_col1" class="data row5 col1" >(731, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc594_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fc594_row6_col1" class="data row6 col1" >(314, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc594_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fc594_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc594_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fc594_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc594_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fc594_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc594_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fc594_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc594_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fc594_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fc594_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_fc594_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fc594_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_fc594_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fc594_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_fc594_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fc594_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_fc594_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fc594_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_fc594_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fc594_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_fc594_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fc594_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fc594_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_fc594_row18_col1" class="data row18 col1" >8858</td>
#     </tr>
#   </tbody>
# </table>

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_74bcc th {
#   text-align: left;
# }
# #T_74bcc_row0_col0, #T_74bcc_row0_col2, #T_74bcc_row0_col4, #T_74bcc_row1_col0, #T_74bcc_row1_col1, #T_74bcc_row1_col2, #T_74bcc_row1_col3, #T_74bcc_row1_col4, #T_74bcc_row1_col5, #T_74bcc_row1_col6, #T_74bcc_row1_col7, #T_74bcc_row2_col0, #T_74bcc_row2_col1, #T_74bcc_row2_col3, #T_74bcc_row2_col5, #T_74bcc_row2_col6, #T_74bcc_row2_col7, #T_74bcc_row3_col0, #T_74bcc_row3_col1, #T_74bcc_row3_col2, #T_74bcc_row3_col3, #T_74bcc_row3_col4, #T_74bcc_row3_col5, #T_74bcc_row3_col6, #T_74bcc_row3_col7, #T_74bcc_row4_col0, #T_74bcc_row4_col1, #T_74bcc_row4_col2, #T_74bcc_row4_col3, #T_74bcc_row4_col4, #T_74bcc_row4_col5, #T_74bcc_row4_col6, #T_74bcc_row4_col7, #T_74bcc_row5_col0, #T_74bcc_row5_col1, #T_74bcc_row5_col2, #T_74bcc_row5_col3, #T_74bcc_row5_col4, #T_74bcc_row5_col5, #T_74bcc_row5_col6, #T_74bcc_row5_col7, #T_74bcc_row6_col0, #T_74bcc_row6_col1, #T_74bcc_row6_col2, #T_74bcc_row6_col3, #T_74bcc_row6_col4, #T_74bcc_row6_col5, #T_74bcc_row6_col6, #T_74bcc_row6_col7, #T_74bcc_row7_col0, #T_74bcc_row7_col1, #T_74bcc_row7_col2, #T_74bcc_row7_col3, #T_74bcc_row7_col4, #T_74bcc_row7_col5, #T_74bcc_row7_col6, #T_74bcc_row7_col7, #T_74bcc_row8_col0, #T_74bcc_row8_col1, #T_74bcc_row8_col2, #T_74bcc_row8_col3, #T_74bcc_row8_col4, #T_74bcc_row8_col5, #T_74bcc_row8_col6, #T_74bcc_row8_col7, #T_74bcc_row9_col0, #T_74bcc_row9_col1, #T_74bcc_row9_col2, #T_74bcc_row9_col3, #T_74bcc_row9_col4, #T_74bcc_row9_col5, #T_74bcc_row9_col6, #T_74bcc_row9_col7, #T_74bcc_row10_col0, #T_74bcc_row10_col1, #T_74bcc_row10_col2, #T_74bcc_row10_col3, #T_74bcc_row10_col4, #T_74bcc_row10_col5, #T_74bcc_row10_col6, #T_74bcc_row10_col7, #T_74bcc_row11_col0, #T_74bcc_row11_col1, #T_74bcc_row11_col2, #T_74bcc_row11_col3, #T_74bcc_row11_col4, #T_74bcc_row11_col5, #T_74bcc_row11_col6, #T_74bcc_row11_col7, #T_74bcc_row12_col0, #T_74bcc_row12_col1, #T_74bcc_row12_col2, #T_74bcc_row12_col3, #T_74bcc_row12_col4, #T_74bcc_row12_col5, #T_74bcc_row12_col6, #T_74bcc_row12_col7, #T_74bcc_row13_col0, #T_74bcc_row13_col1, #T_74bcc_row13_col2, #T_74bcc_row13_col3, #T_74bcc_row13_col4, #T_74bcc_row13_col5, #T_74bcc_row13_col6, #T_74bcc_row13_col7 {
#   text-align: left;
# }
# #T_74bcc_row0_col1, #T_74bcc_row0_col3, #T_74bcc_row0_col5, #T_74bcc_row0_col6, #T_74bcc_row0_col7, #T_74bcc_row2_col2, #T_74bcc_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_74bcc_row0_col8, #T_74bcc_row1_col8, #T_74bcc_row2_col8, #T_74bcc_row4_col8, #T_74bcc_row5_col8, #T_74bcc_row6_col8, #T_74bcc_row7_col8, #T_74bcc_row8_col8, #T_74bcc_row9_col8, #T_74bcc_row10_col8, #T_74bcc_row11_col8, #T_74bcc_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_74bcc_row3_col8, #T_74bcc_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_74bcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74bcc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_74bcc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_74bcc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_74bcc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_74bcc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_74bcc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_74bcc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_74bcc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_74bcc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74bcc_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_74bcc_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_74bcc_row0_col1" class="data row0 col1" >0.8166</td>
#       <td id="T_74bcc_row0_col2" class="data row0 col2" >0.8521</td>
#       <td id="T_74bcc_row0_col3" class="data row0 col3" >0.7561</td>
#       <td id="T_74bcc_row0_col4" class="data row0 col4" >0.7883</td>
#       <td id="T_74bcc_row0_col5" class="data row0 col5" >0.7704</td>
#       <td id="T_74bcc_row0_col6" class="data row0 col6" >0.6181</td>
#       <td id="T_74bcc_row0_col7" class="data row0 col7" >0.6199</td>
#       <td id="T_74bcc_row0_col8" class="data row0 col8" >0.0770</td>
#     </tr>
#     <tr>
#       <th id="T_74bcc_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_74bcc_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_74bcc_row1_col1" class="data row1 col1" >0.8139</td>
#       <td id="T_74bcc_row1_col2" class="data row1 col2" >0.8610</td>
#       <td id="T_74bcc_row1_col3" class="data row1 col3" >0.7356</td>
#       <td id="T_74bcc_row1_col4" class="data row1 col4" >0.7969</td>
#       <td id="T_74bcc_row1_col5" class="data row1 col5" >0.7633</td>
#       <td id="T_74bcc_row1_col6" class="data row1 col6" >0.6106</td>
#       <td id="T_74bcc_row1_col7" class="data row1 col7" >0.6137</td>
#       <td id="T_74bcc_row1_col8" class="data row1 col8" >0.2900</td>
#     </tr>
#     <tr>
#       <th id="T_74bcc_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_74bcc_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_74bcc_row2_col1" class="data row2 col1" >0.8084</td>
#       <td id="T_74bcc_row2_col2" class="data row2 col2" >0.8674</td>
#       <td id="T_74bcc_row2_col3" class="data row2 col3" >0.6857</td>
#       <td id="T_74bcc_row2_col4" class="data row2 col4" >0.8185</td>
#       <td id="T_74bcc_row2_col5" class="data row2 col5" >0.7435</td>
#       <td id="T_74bcc_row2_col6" class="data row2 col6" >0.5932</td>
#       <td id="T_74bcc_row2_col7" class="data row2 col7" >0.6015</td>
#       <td id="T_74bcc_row2_col8" class="data row2 col8" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_74bcc_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_74bcc_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_74bcc_row3_col1" class="data row3 col1" >0.7975</td>
#       <td id="T_74bcc_row3_col2" class="data row3 col2" >0.8424</td>
#       <td id="T_74bcc_row3_col3" class="data row3 col3" >0.6924</td>
#       <td id="T_74bcc_row3_col4" class="data row3 col4" >0.7890</td>
#       <td id="T_74bcc_row3_col5" class="data row3 col5" >0.7354</td>
#       <td id="T_74bcc_row3_col6" class="data row3 col6" >0.5729</td>
#       <td id="T_74bcc_row3_col7" class="data row3 col7" >0.5780</td>
#       <td id="T_74bcc_row3_col8" class="data row3 col8" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_74bcc_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_74bcc_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_74bcc_row4_col1" class="data row4 col1" >0.7907</td>
#       <td id="T_74bcc_row4_col2" class="data row4 col2" >0.8320</td>
#       <td id="T_74bcc_row4_col3" class="data row4 col3" >0.7259</td>
#       <td id="T_74bcc_row4_col4" class="data row4 col4" >0.7560</td>
#       <td id="T_74bcc_row4_col5" class="data row4 col5" >0.7386</td>
#       <td id="T_74bcc_row4_col6" class="data row4 col6" >0.5645</td>
#       <td id="T_74bcc_row4_col7" class="data row4 col7" >0.5670</td>
#       <td id="T_74bcc_row4_col8" class="data row4 col8" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_74bcc_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_74bcc_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_74bcc_row5_col1" class="data row5 col1" >0.7893</td>
#       <td id="T_74bcc_row5_col2" class="data row5 col2" >0.8494</td>
#       <td id="T_74bcc_row5_col3" class="data row5 col3" >0.6959</td>
#       <td id="T_74bcc_row5_col4" class="data row5 col4" >0.7684</td>
#       <td id="T_74bcc_row5_col5" class="data row5 col5" >0.7284</td>
#       <td id="T_74bcc_row5_col6" class="data row5 col6" >0.5574</td>
#       <td id="T_74bcc_row5_col7" class="data row5 col7" >0.5609<

# %%
print(best)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Up to you!
predict_model(best, titanic.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_98552">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98552_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_98552_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_98552_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_98552_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_98552_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_98552_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_98552_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_98552_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98552_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98552_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_98552_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_98552_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_98552_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_98552_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_98552_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_98552_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_98552_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#       pclass  sex   age  sibsp  parch     fare  survived  prediction_label  \
# 1301       3    1  45.5      0      0   7.2250         0                 0
# 1304       3    0  14.5      1      0  14.4542         0                 1
# 1306       3    1  26.5      0      0   7.2250         0                 0
# 1307       3    1  27.0      0      0   7.2250         0                 0
# 1308       3    1  29.0      0      0   7.8750         0                 0
#
#       prediction_score
# 1301            0.9800
# 1304            0.8700
# 1306            0.8993
# 1307            0.9410
# 1308            1.0000

# %% [markdown]
# ##Save the model

# %%
# Up to you!
save_model(best, 'titanic_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['pclass', 'sex', 'age', 'sibsp',
#                                               'parch', 'fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   TransformerWrapper...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=-1,
#                                          oob_score=False, random_state=123,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'titanic_model.pkl')

# %%
#plot the performance of the model
plot_model(best, plot = 'auc')

# %%
#plot the performance of the model using confusion matrix
plot_model(best, plot = 'confusion_matrix')
